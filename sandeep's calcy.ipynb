# %%
# print("welcome to SANDEEP'S SPECIAL PROGRAM")
print("how to use\nit is easy to use\njust let me know the serial no. whose you want to calculate\njust enter the serial no.")
print("1) TRIANGLE")
print("2) CIRCLE")
print("3) RECTANGLE")
print("4) SQUARE")
print("5) RHOMBUS")
print("6) CUBE")
print("7) CUBOID ")
print("8) CONE")
print("9) CYLLINDER")
print("10) SPHRERE")
print("11) HEMISPHERE")
print("12) Hollow sphere")
print("13) Hollow hemisphere")
print()
import math
import numpy as np
import cmath as cm

n = int(input("enter the no. : "))
if n == 1:
    print("tell me what i have to CALCULATE")
    print("1) AREA")
    print("2) PERIMETER")
    n1 = int(input("enter the serial no. :"))
    if n1 == 1:
        print("1) YES")
        print("2) NO")
        n2 = input("let me know if you know the height of a triangle: ")
        if n2 == "1":
            n3 = float(input("enter the height of the triangle: "))
            n4 = float(input("enter the base of the triangle: "))
            print("  ")
            print("  ")
            print("solution")
            print("  ")
            print("we have,\nheight = ",n3,"\nbase = ",n4)
            print("FORMULA WE USE = 1/2*Height of a triangle*Base of a triangle")
            print("NOW,\nPutting the values\n= 1/2*",n3,"*",n4)
            cal = n3*n4*0.5
            print("the area of a triangle is= ",cal,"sq.units     {ignore 0j part}") 
        else:
            import math
            
            print("here we apply herons formula")
            io = float(input("enter the side of a triangle: "))
            io1 = float(input("enter the another side of a triangle: "))
            io2 = float(input("enter the another side of triangle: "))
            io3 = io+io1+io2
            io4 = io3/2
            io5 = io4-io
            io6 = io4-io1
            io7 = io4-io2
            io8 = io4*io5*io6*io7
            import math
            import math
            
            io9 = cm.sqrt(io8)
            print(" ")
            print("Solution:")
            
            print("The formula given by Heron about the area of a triangle = √s(s-a)(s-b)(s−c)\nWe have,\nside(a) =",io,"\nside(b) =",io1,"\nside(c) = ",io3)
            print("now,\nsemi perimeter(s) = (a+b+c)/2\n=",io,"+",io1,"+",io2,"\n=",io3,"/2\n=",io4)
            print("=>(s-a)=(",io4,"-",io,")\n=",io5)
            print(" ")
            print("=>(s-b)=(",io4,"-",io1,")\n=",io6)
            print(" ")
            print("=>(s-c)=(",io4,"-",io2,")\n=",io7)
            print(" ")
            print("=s(s-a)(s-b)(s−c)\n=",io4,"*",io5,"*",io6,"*",io7,"\n=",io8)
            print("√s(s-a)(s-b)(s−c)=√",io8,"=",io9)
            print("therefore,\nthe required area of triagle is ",io9,"sq.units  {ignore 0j part}")
            
            
    else:
        n11 = float(input("enter the any one side of a triangle"))
        n12 = float(input("enter the another side of a triangle"))
        n13 = float(input("enter the another side of a triangle"))
        print("  ")
        print("  ")
        print("solution")
        print("  ")
        print("we have,\nside = ",n11,"\nside = ",n12,"\nside = ",n13)
        print("  ")
        
        print("perimeter = sum of all side\nso,",n11,"+",n12,"+",n13)
        cal1 = n11+n12+n13
        print("The required perimeter of a triangle: ",cal1,"unit")
        
        
elif n == 2:
    
    print("1) AREA")
    
    print("2) PERIMETER")
    
    pp = int(input("TELL ME WHAT TO CALCULATE:"))
    if pp == 1:
        print("please note that\n diameter is the twice of radious\ni.e if Diameter i 4 then radious is = 2 nd vise versa")
        q =  float(input("enter the radious of a circle: "))
        pi = math.pi
        l = q**2
        ll = pi*l
        print("  ")               
        print("solution")
        print("we have,\nr = ",q)
        print("  ")
        print("so,\nthe area of a circle is given by = π r²\nwe know, \n π=3.14\nr²=",l)
        print("therefore the area of circle is equal to",ll,"sq.units")
    else:
        print("please note that\n diameter is the twice of radious\ni.e if Diameter i 4 then radious is = 2 nd vise versa")
        s = float(input("enter the radious of a circle: "))
        pi = math.pi
        ok = 2*s*pi
                  
        print("  ")
                  
        print("solution")
                  
        print("  ")
        print("we have,\nr = ",q)
        
                  
        print("so,\nthe perimeter of a circle is given by = 2πr\nwe know, \n π=3.14\nr=",s)
                  
        print("therefore the perimeter of a circle is equal to",ok,"unit")
elif n == 3:
    print("1) AREA")
    
    print("2) PERIMETER")
    
    po = int(input("TELL ME WHAT TO CALCULATE:"))
    if po == 1:
        li = float(input("enter the length of a rectangle :"))
        li2 = float(input("enter the breadth of a rectangle :"))
        op = li*li2
        print("  ")
        print("Solution-:")
        print("  ")
        print("We have,")
        print("  ")
        print("length = ",li)
        print("breadth = ",li2)
        print("now,")
        print("the area of a rectangle is = L*B")
        print("putting the value of length nd breadth\nL*B = ",li,"*",li2)
        print("=",op)
        print("Therefore,\nthe area of a rectangle is equal to ",op,"sq.units")
    else:
        ki = float(input("enter the length of a rectangle :"))
        ki2 = float(input("enter the breadth of a rectangle :"))
        ko = ki+ki2
        ioiio = ko*2
        print(" ")
        print("Solution:-")
        
        print("We have,")
        print(" ")
        print("length = ",ki)
        print("breadth = ",ki2)
        print("now,")
        print("the perimeter of a recangle is given by : 2(L+B)\nso,\n2(L+B) =2(",ki,"+",ki2,")")
        print("= 2*",ko)
        print("= ",ioiio)
        print("Therefore,\nthe perimeter of a rectangle is equal to ",ioiio,"unit")
elif n == 4:
    print("1) AREA")
    print("2) Perimeter")
    MO = int(input("enter the no."))
    if MO ==1:
        ji = float(input("enter the side of a square: "))
        jii = ji**2
        print(" ")
        print("Solution:-")
        
        print("We have,")
        print(" ")
        print("side =",ji,"\narea of a square = side*side\n=",ji,"*",ji)
        print("=",jii)
        print("therefore,\nthe area of a square is equal to ",jii,"sq.units")
    else:
        gi = float(input("enter the side of a square"))
        gii = gi*4
        print(" ")
        print("Solution:-")
        
        print("We have,")
                   
        print(" ")
        print("side =",gi,"\nperimeter of a square = 4*side\n= 4*",gi)
        print("=",gii)
        print("therefore the perimeter of a square is equal to ",gii,"units")
elif n ==5:
    print("1 AREA")
    print("2) PERIMETER")
    mi = int(input("enter the serial no.:  "))
    if mi == 1:
        print("1) iknow thw one diagonal nd any one side of rhombus : ")
        print("2) i know both the diagonals : ")
        xz = int(input(" enter the serial no."))
        if xz == 1:
            f = float(input("enter the any one diagonal: "))
            g = float(input("tell me any one side of rhombus : "))
            v = f/2
            g1 = v**2
            g2 = g**2
            f1 = g1+g2
            f2 = np.sqrt(f1)
            f3 = f2*2
            aa = f*f3
            aaa = aa/2
            print(" ")
            print("Solution:")
            print("we have,")
            print("The diagonal of a rhombus(D1):",f)
            print("The side of a rhombus is equal to: ",g)
            print("Here,\n as we know that the diagonals of a rhombus is a perpendicular bisector\nso,\nwe use pythagoras theorem to find second diagonal")
            
            print(" half of diagonal = ",v)
            print("side of the rhombus = ",g)
            print("in triangle(name)\n",v,"²+",g,"²+ = (diagonal)² {From pythagoras}")
            print("(diagonal)²= ",g1,"+",g2)
            print("(diagonal)² = ",f1)
            print("diagonal =",f2)
            print("diagonal =",f2,"*2 {as this is the half of diagonal so we have to multiply by 2}")
            print("diagonal = ",f3)
            print("area of rhombus is equal to = product of diagonals/2\n=",f,"*",f3,"\n=",aa,"/2\n",aaa)
            print("so, the required area of a rhombus is ",aaa,"sq.units {ignore 0j part}")
        else:
            gh = float(input("enter the diagonal: "))
            oh = float(input("enter the  diagonal: "))
            kj = gh*oh
            kl = kj/2
            print(" ")
            print("Solution: ")
            print("We have,")
            print("The diagonal of a rhombus(D1):",gh)
            print("The diagonal of a rhombus(D2):",oh)
            print("The area of a rhombus is equal to = (D1*D2)/2")
            print("so,\nThe area of a rhombus is equal to =(",gh,"*",oh,")/2\n=",kl)
            print("the required area of a rhombus is equal to",kl,"sq.units  {ignore 0j part}")
    else:
        xz = float(input("enter the side of a rhombus: "))
        aaas = xz*4
        print(" ")
        print("Solution:-")
        
        print("We have,")
                   
        print(" ")
        print("side =",xz,"\nperimeter of a rhombus = 4*side\n= 4*",xz)
        print("=",xz)
        print("therefore the perimeter of a rhombus is equal to ",aaas,"unit")
elif n == 6:
    print("1) Total Surface Area (TSA) of cube")
    print("2) Lateral Surface Area(LSA) of cube")
    print("3) Volume of cube")
    print("4) Diagonal of a cube ")
    print("5) Perimeter of cube")
    print()
    y = int(input("enter the serial no.: "))
    if y ==1:
        f = float(input("enter the side of a cube: "))
        z = f**2
        c = 6*z
        print(" ")
        print("Solution:")
        print("We have,")
        print("The side of a cube = ",f)
        print("The  total surface of a cube = 6(side)²\nThe  total surface of a cube =6*",f,"²")
        print("The  total surface of a cube = 6*",z)
        print("now,\nthe required total surface of a cube = ",c,"sq.units")
    elif y == 2:
        to =  float(input("enter the side of a cube: "))
        z1 = to**2
        c1 = 4*z
        print(" ")
        print("Solution:")
        print("We have,")
        print("The side of a cube = ",to)
        print("The  lateral surface of a cube = 4(side)²\nThe  lateral surface of a cube =4*",to,"²")
        print("The  lateral surface of a cube = 4*",z1)
        print("now,\nthe required lateral surface of a cube = ",c1,"sq.units")
    elif y ==3:
        to1 = float(input("enter the side of a cube: "))
        z1 = to1**3
        
        print(" ")
        print("Solution:")
        print("We have,")
        print("The side of a cube = ",to1)
        print("The volume of a cube = (side)³\nThe  volume of a cube =",to,"³")
        print("The  volume of a cube = ",z1)
        print("now,\nthe required volume of a cube = ",z1,"cubic units")
        
    elif y == 4:
        to11 = float(input("enter the side of a cube: "))
        jko = cm.sqrt(3)
        ooi = jko*to11
        print(" ")
        print("Solution:")
        print("We have,")
        print("The side of a cube = ",to11)
        print("The diagonal of a cube= √3(side)\nThe diagonal of a cube= √3*",to11)
        print("The diagonal of a cube= ",jko,"*",to11)
        print("Hence,\nThe diagonal of a cube= ",ooi,"units {ignore 0j part}")
    elif y ==5:
        lk = float(input("enter the side of a cube: "))
        uu = 12*lk
        print(" ")
        print("Solution:")
        print("We have,")
        print("The side of a cube = ",lk)
        print("The  Perimeter of a cube = 12(side)\nThe  Perimeter of a cube =12*",lk)
        
        print("now,\nthe required Perimeter of a cube = ",uu,"units")
elif n == 7:
    print("1) Total Surface Area (TSA) of cuboid")
    print("2) Lateral Surface Area(LSA) of cuboid")
    print("3) Volume of cuboid")
    print("4) Diagonal of a cuboid ")
    print("5) Perimeter of cuboid")
    print()
    y8 = int(input("enter the serial no.: "))
    if y8 ==1:
        f8 = float(input("enter the length of a cuboid: "))
        f81 = float(input("enter the breadth of a cuboid: "))
        f82= float(input("enter the height of a cuboid: "))
        mom = f8*f81
        mmm = f8*f82
        km = f81*f82
        lol = mom+mmm+km
        lol1 = lol*2
        print(" ")
        print("Solution:")
        print("We have,")
        print("The length of a cuboid = ",f8)
        print("The breadth of a cuboid = ",f81)
        print("The height of a cuboid = ",f82)
        print("The  total surface area of a cuboid = 2 (length × breadth + breadth × height + length × height)\nThe  total surface area of a cuboid = 2(",f8,"*",f81,"+",f81,"*",f82,"+",f82,"*",f8,")\nThe  total surface area of a cuboid = 2(",mom,"+",km,"+",mmm,")")
        print("The  total surface area of a cuboid = 2*",lol)
        print("The  total surface area of a cuboid = ",lol1)
        print("Hence,\nThe  total surface area of a cuboid = ",lol1,"sq.units")
    elif y8 ==2:
        k1 = float(input("enter the length of a cuboid: "))
        k2 = float(input("enter the breadth of a cuboid: "))
        k3= float(input("enter the height of a cuboid: "))
        uy = k1+k2
        ty = 2*uy*k3
        print(" ")
        print("Solution:")
        print("We have,")
        print("The length of a cuboid = ",k1)
        print("The breadth of a cuboid = ",k2)
        print("The height of a cuboid = ",k3)
        print("The  lateral surface area of a cuboid = 2(length + breadth) × height")
        print("= 2(",k1,"+",k2,")",k3)
        print("= 2*",uy,"*",k3)
        print("= ",ty)
        print("Hence,\nThe  lateral surface area of a cuboid = ",ty,"sq.units")
    elif y8 == 3:
        k96 = float(input("enter the length of a cuboid: "))
        k20= float(input("enter the breadth of a cuboid: "))
        k30= float(input("enter the height of a cuboid: "))
        k4 = k1*k2*k3
        print(" ")
        print("Solution:")
        print("We have,")
        print("The length of a cuboid = ",k96)
        print("The breadth of a cuboid = ",k20)
        print("The height of a cuboid = ",k30)
        print("The Volume of a cuboid = Length × Breadth × Height")
        print("= ",k96,"*",k20,"*",k30)
        print("= ",k4)
        print("Hence,\nThe volume of a cuboid = ",k4,"cubic units")
    elif y8 == 4:
        k100 = float(input("enter the length of a cuboid: "))
        k201= float(input("enter the breadth of a cuboid: "))
        k302= float(input("enter the height of a cuboid: "))
        z1 = k100**2
        z2 = k201**2
        z0 = k302**2
        z01 = z1+z2+z0
        z001= cm.sqrt(z01)
        print(" ")
        print("Solution:")
        print("We have,")
        print("The length of a cuboid = ",k100)
        print("The breadth of a cuboid = ",k201)
        print("The height of a cuboid = ",k302)
        print("The diagonal of a cuboid = √(l² + b² + h²)")
        print("= √(",k100,"²+",k201,"²+",k302,"²+)")
        print("= √(",z1,"+",z2,"+",z0)
        print("=  √",z01)
        print("= ",z001)
        print("Hence,\nThe diagonal of a cuboid = ",z001,"units")
    elif y8 ==5:
        k200 = float(input("enter the length of a cuboid: "))
        k202= float(input("enter the breadth of a cuboid: "))
        k303= float(input("enter the height of a cuboid: "))
        kik = k200+k202+k303
        lil = 4*kik
        print(" ")
        print("Solution:")
        print("We have,")
        print("The length of a cuboid = ",k200)
        print("The breadth of a cuboid = ",k202)
        print("The height of a cuboid = ",k303)
        print("The perimeter of a cuboid = 4(l + b + h)")
        print("The perimeter of a cuboid = 4(",k200,"+",k202,"+",k303,")\n= 4*",kik)
        
        print("= ",lil)
        print("Hence,\nThe perimeter of a cuboid = ",lil,"units")
elif n ==8:
    print("1) Total surface area")
    print("2) Volume")
    kjk = int(input("Enter the serial no."))
    if kjk ==1:
        print("slant height is  given?")
        print("1) yes")
        print("2) no")
        tht = float(input("enter the no. = "))
        if tht == 1:
            uy = float(input("enter the Radious of cone: "))
            ytr = float(input("enter the Slant height of a cone : "))
            mj = math.pi
            mb = mj*uy
            nc = uy+ytr
            mz = nc*mb
            print(" ")
            print("Solution:")
            print("We have,")
            print("The radious of a cone = ",uy)
            print(" slant height of cone(l): ",ytr)
            print("the total surface are of cone is given by:  πr(l + r)")
            print("so,\n=",mj,"*",uy,"(",ytr,"+",uy,")")
            print("= ",mb,"(",nc,")\n= ",mz)
            print("therefore,\nThe total surface area of cone is ",mz,"sq.units")
        elif tht == 2:
            mk = float(input("enter the Radious of cone: "))
            zr = float(input("enter the height of a cone : "))
            ui = mk**2
            jg = zr**2
            cv = ui+jg
            asd = cm.sqrt(cv)
            bn = math.pi
            xc = bn*mk
            ol = mk+asd
            vz = ol*xc
            print(" ")
            print("Solution:")
            print("We have,")
            print("The radious of a cone(r) = ",mk)
            print("  height of cone(h): ",zr)
            print("the total surface area of cone is given by:  πr(l + r)")
            print(" Here we use pythagoras Theorem to find slant height")
            print("so,\nin triangle(triangle name)\nl²=r²+h²\n=>l²=",mk,"²+",zr,"²\n=>l²=",ui,"+",jg)
            print("=>l²=",ol)
            print("=>l=√",ol,"\n=> l=",asd)
            print("πr(l + r)=",bn,"*",mk,"(",asd,"+",mk,")")
            print("πr(l + r) = ",xc,"*",ol)
            print("πr(l + r)  =",vz)
            print("therefore,\nThe total surface area of cone is ",vz,"sq.units")
    elif kjk ==2:
        print("slant height is  given?")
        print("1) yes")
        print("2) no")
        that = float(input("enter the no. = "))
        if that ==1:
            ouy = float(input("enter the Radious of cone: "))
            ptr = float(input("enter the Slant height of a cone : "))
            mij = math.pi
            iki = ouy**2
            kik = ptr**2
            qwe = kik-iki
            aqw = cm.sqrt(qwe)
            zas = mij*iki*aqw/3
            print(" ")
            print("Solution:")
            print("We have,")
            print("The radious of a cone(r) = ",ouy)
            print("Slant height of cone(l): ",ptr)
            print("the volume of cone is given by:  ⅓πr²h")
            print(" Here we use pythagoras Theorem to find  height")
            print("so,\nin triangle(triangle name)\nh²=l²-r²\n=>h²=",ptr,"²-",ouy,"²\n=>h²=",kik,"-",iki)
            print("=>h²=",qwe)
            print("=>h=√",qwe,"\n=> h=",aqw)
            print("now,\n=>⅓πr²h = ⅓",mij,"*",iki,"*",aqw)
            print("=>⅓πr²h = ",zas)
            print("therefore,\nThe volume of cone is ",zas,"cubic units")
        elif that ==2:
            ouy1 = float(input("enter the Radious of cone: "))
            ptr1 = float(input("enter the height of a cone : "))
            mij1 = math.pi
            iki14 = ouy1**2
            zas1 = mij1*iki1*ptr1/3
            print(" ")
            print("Solution:")
            print("We have,")
            print("The radious of a cone(r) = ",ouy1)
            print("height of cone(h): ",ptr1)
            print("the volume of cone is given by:  ⅓πr²h")
            print("⅓πr²h = ⅓",mij1,"*",iki14,"*",ptr1)
            print("=>⅓πr²h = ",zas1)
            print("therefore,\nThe volume of cone is ",zas1,"cubic units")
elif n==9:
    print("1) Lateral surface area")
    print("2) Total surface area")
    print("3) curved surface area")
    print("4) volume")
    print()
    af = int(input("enter the no. "))
    if af ==1:
        axa = float(input("etnert the radious : "))
        axa2 = float(input("enter the height : "))
        huj = math.pi
        dddf = huj*axa*axa2*2
        print(" ")
        print("Solution:")
        print("We have,")
        print("The radious of a Cylinder(r) = ",axa)
        print("height of Cylinder(h): ",axa2)
        print("the Lateral surface area is given by:  2πrh")
        print("so,\n2πrh= 2*",huj,"*",axa,"*",axa2)
        print("2πrh= ",dddf)
        print("therefore,\nThe Lateral surface area is ",dddf,"sq.units")
    elif af ==2:
        ax1a = float(input("etnert the radious : "))
        ax2a = float(input("enter the height : "))
        hu1j = math.pi
        nu1 = 2*hu1j*ax1a
        vv1 = ax1a+ax2a
        aak = vv1*nu1
        print(" ")
        print("Solution:")
        print("We have,")
        print("The radious of a Cylinder(r) = ",ax1a)
        print("height of Cylinder(h): ",ax2a)
        print("the Total Surface Area of Cylinder is given by: 2πr(r+h)")
        print("so,\n 2πr(r+h)= 2*",huj,"*",ax1a,"(",ax1a,"+",ax2a,")")
        print(" 2πr(r+h) = ",nu1,"(",vv1,")")
        print(" 2πr(r+h) = ",aak)
        print("therefore,\nThe Total Surface Area of Cylinder is ",aak,"sq.units")
    elif af ==3:
        axaq = float(input("etnert the radious : "))
        axa2q = float(input("enter the height : "))
        hujq = math.pi
        dddfq = hujq*axaq*axa2q*2
        print(" ")
        print("Solution:")
        print("We have,")
        print("The radious of a Cylinder(r) = ",axaq)
        print("height of Cylinder(h): ",axa2q)
        print("the curved surface area is given by:  2πrh")
        print("so,\n2πrh= 2*",hujq,"*",axaq,"*",axa2q)
        print("2πrh= ",dddfq)
        print("therefore,\nThe curved surface area is ",dddfq,"sq.units")
    elif af ==4:
        axat = float(input("etnert the radious : "))
        axa2t = float(input("enter the height : "))
        hujqt = math.pi
        cxz = axat**2
        dddfqt = hujqt*cxz*axa2t
        print(" ")
        print("Solution:")
        print("We have,")
        print("The radious of a Cylinder(r) = ",axat)
        print("height of Cylinder(h): ",axa2t)
        print("The Volume of Cylinder is given by: πr²h")
        print("so,\nπr²h=",hujqt,"*",axat,"²*",axa2t)
        print("πr²h=",hujqt,"*",cxz,"*",axa2t)
        print("πr²h= ",dddfqt)
        print("therefore,\nThe Volume of Cylinder is ",dddfqt,"cubic units")
elif n ==10:
    print("1) Surface Area of a Sphere")
    print("2) Volume of a Sphere")
    axz = int(input("enter the serial no. "))
    if axz == 1:
        print("please note that\n diameter is the twice of radious\ni.e if Diameter is 4 then radious is = 2 nd vise versa") 
        ozx = float(input("enter the radious of sphere:  "))
        uyyt = ozx**2
        jzx = math.pi
        uyt = 4*uyyt*jzx
        print(" ")
        print("Solution:")
        print("We have,")
        print("The radious of a Sphere(r) = ",ozx)
        print("The Surface Area of a Sphere is given by: 4πr²")
        print("so,\n4πr²=4*",jzx,"*",ozx,"²")
        print("4πr²=4*",uyt,"*",uyyt)
        print("4πr²= ",uyt)
        print("therefore,\nThe Surface Area of a Sphere is ",uyt,"sq.units")
    elif axz ==2:
        print("please note that\n diameter is the twice of radious\ni.e if Diameter is 4 then radious is = 2 nd vise versa") 
        ozp = float(input("enter the radious of sphere:  "))
        uyyp = ozp**3
        jzxp = math.pi
        uytp = 4/3*uyyp*jzx
        print(" ")
        print("Solution:")
        print("We have,")
        print("The radious of a Sphere(r) = ",ozx)
        print("The Volume of a Sphere is given by:(4⁄3)πr³")
        print("so,\n(4⁄3)πr³=(4⁄3)*",jzxp,"*",ozp,"³")
        print("(4⁄3)πr³=(4⁄3)*",jzxp,"*",uyyp)
        print("(4⁄3)πr³= ",uytp)
        print("therefore,\n The  Volume of a Sphere is ",uytp,"cubic units")
elif n==11:
    print("1)  curved surface area ")
    print("2) total surface area ")
    print("3) volume")
    erw = int(input(" enter the no. "))
    if erw ==1:
        print("please note that\n diameter is the twice of radious\ni.e if Diameter is 4 then radious is = 2 nd vise versa") 
        tut = float(input("enter the radious: "))
        ewq = math.pi
        owid = tut**2
        uye = 2*owid*ewq
        print(" ")
        print("Solution:")
        print("we have,\nRadious(r) = ",tut)
        
        print("so,\nthe  curved surface area of a hemisphere is given by = 2πr²\nwe know,\nπ=3.14\nr²=",owid)
        print("2πr²= 2*",ewq,"*",owid)
        print("2πr² = ",uye)
        print("therefore the  curved surface area of a hemisphere is equal to",uye,"{ignore 0j part}")
    elif erw ==2:
        print("please note that\n diameter is the twice of radious\ni.e if Diameter is 4 then radious is = 2 nd vise versa") 
        tut1 = float(input("enter the radious: "))
        ewq1 = math.pi
        owi71 = tut1**2
        uye1 = 3*owi71*ewq1
        print(" ")
        print("Solution:")
        print("We have,")
        print("The radious of a Sphere(r) = ",tut1)
        print("so,\nthe  total surface area of a hemisphere is given by = 3πr²\nwe know,\nπ=3.14\nr²=",owi71)
        print("3πr²= 3*",ewq1,"*",owi71)
        print("3πr² = ",uye1)
        print("therefore the  total surface area of a hemisphere is equal to",uye1,"cubic units")
    elif erw ==3:
        print("please note that\n diameter is the twice of radious\ni.e if Diameter is 4 then radious is = 2 nd vise versa")
        tta = float(input("enter the radious of hemisphere = "))
        eda = math.pi
        hhh = tta**3
        saa = 2*hhh*eda/3
        print(" ")
        print("Solution:")
        print("We have,")
        print("radious of hemisphere is: ",tta)
        print("the volume of hemisphere is equal to = (⅔)𝜋r³")
        print("(⅔)𝜋r³= (⅔)",eda,"*",tta,"³")
        print("(⅔)𝜋r³ = (⅔)",eda,"*",hhh)
        print("(⅔)𝜋r³ = ",saa)
        print("therefore,\nthe  volume of a hemisphere is equal to",saa,"cubic units")
elif n ==12:
    print("1) surface area ")
    print("2) volume")
    oio = int(input("enter the no. "))
    if oio ==1:
        print("please note that\n diameter is the twice of radious\ni.e if Diameter is 4 then radious is = 2 nd vise versa")
        ozxpp = float(input("enter the radious of hollow sphere: "))
        uyytpp = ozxpp**2
        jzxpp = math.pi
        uytpp = 4*uyytpp*jzxpp
        print(" ")
        print("Solution:")
        print("We have,")
        print("The radious of a Hollow Sphere(r) = ",ozxpp)
        print("The Surface Area of a Sphere is given by: 4πr²")
        print("so,\n4πr²=4*",jzxpp,"*",ozxpp,"²")
        print("4πr²=4*",uytpp,"*",uyytpp)
        print("4πr²= ",uytpp)
        print("therefore,\nThe Surface Area of a Hollow Sphere is ",uytpp,"sq.units")
    elif oio ==2:
        print("please note that\n diameter is the twice of radious\ni.e if Diameter is 4 then radiu s is = 2 nd vise versa")
        oix = float(input("enter the  outer radius of the  hollow sphere (R) : "))
        liux = float(input("enter the  internal  radius of the  hollow sphere (r) : ")) 
        ghy = oix**3
        ghw = liux**3
        okik = ghy-ghw
        klo = math.pi
        kioi = 4*klo*okik/3
        print(" ")
        print("Solution:")
        print("We have,")
        print("The  outer radius of the  hollow sphere (R) : ",oix)
        print("The  internal  radius of the  hollow sphere (r) : ",liux)
        print("The Volume of a Hollow Sphere is given by: (4⁄3)×π×(R³−r³)")
        print("so,\n(4⁄3)×π×(R³−r³)=(4⁄3)*",klo,"*(",oix,"³-",liux,"³)")
        print("(4⁄3)×π×(R³−r³)=(4⁄3)*",klo,"*(",ghy,"-",ghw,")")
        print("(4⁄3)×π×(R³−r³)=(4/3)*",klo,"*",okik)
        print("(4⁄3)×π×(R³−r³)= ",kioi)
        print("therefore,\n The  Volume of a Sphere is ",kioi,"cubic units")
elif n==13:
    print("1) Total surface area of hollow hemisphere")
    print("2) volume of hollow hemisphere")
    rtr = int(input("enter the no. "))
    if rtr == 1:
        print("please note that\n diameter is the twice of radius\ni.e if Diameter is 4 then radius is = 2 nd vise versa")
        ink = float(input(" enter the outer radius of the hollow hemisphere (R):  "))
        ink1 = float(input("enter the internal radius of hollow hemisphere (r):  "))
        jki = math.pi
        okiw = ink**2
        olol = 3*jki*okiw
        ouyt = ink1 **2
        ioiud = jki*ouyt
        uytww = olol+ioiud
        print(" ")
        print("Solution:")
        print("We have: ")
        print("The outer radius of hollow hemisphere(R): ",ink)
        print("The internal radius of hollow hemisphere(r): ",ink1)
        print("The total surface area of hollow hemisphere is given by: 3πR² + πr²\n3πR² + πr² =3",jki,"*(",ink,")²+",jki,"*(",ink1,")²")
        print(" 3πR² + πr² = 3*",jki,"*(",okiw,")+",jki,"*(",ouyt,")")
        print("3πR² + πr² = ",olol,"+",ioiud)
        print("3πR² + πr² = ",uytww)
        print("therefore,\nThe  surface area of a Hollow Sphere is ",uytww,"sq.units")
    elif rtr == 2:
        print("please note that\n diameter is the twice of radius\ni.e if Diameter is 4 then radius is = 2 nd vise versa")
        oixzz = float(input(" enter the outer radius of the hollow hemisphere (R):  "))
        liuxzz = float(input("enter the internal radius of hollow hemisphere (r):  "))
       
        ghyzz = oixzz**3
        ghwzz = liuxzz**3
        okikzz = ghyzz-ghwzz
        klozz = math.pi
        kioizz = 4*klozz*okikzz/3
        print(" ")
        print("Solution:")
        print("We have,")
        print("The  outer radius of the  hollow hemisphere (R) : ",oixzz)
        print("The  internal  radius of the  hollow hemisphere (r) : ",liuxzz)
        print("The Volume of a Hollow hemiSphere is given by: (2⁄3)×π×(R³−r³)")
        print("so,\n(2⁄3)×π×(R³−r³)=(2⁄3)*",klozz,"*(",oixzz,"³-",liuxzz,"³)")
        print("(2⁄3)×π×(R³−r³)=(2⁄3)*",klozz,"*(",ghyzz,"-",ghwzz,")")
        print("(2⁄3)×π×(R³−r³)=(2⁄3)*",klozz,"*",okikzz)
        print("(2⁄3)×π×(R³−r³)= ",kioizz)
        print("therefore,\n The  Volume of a hemiSphere is ",kioizz,"cubic units")
# Out:
# how to use
# it is easy to use
# just let me know the serial no. whose you want to calculate
# just enter the serial no.
# 1) TRIANGLE
# 2) CIRCLE
# 3) RECTANGLE
# 4) SQUARE
# 5) RHOMBUS
# 6) CUBE
# 7) CUBOID
# 8) CONE
# 9) CYLLINDER
# 10) SPHRERE
# 11) HEMISPHERE
# 12) Hollow sphere
# 13) Hollow hemisphere
